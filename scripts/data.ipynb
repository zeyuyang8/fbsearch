# %%
import pandas as pd


DATA_PATH = "/data/users/zy45/fbsource/fbcode/gen_ai/web_search/genx/scripts/data/scifact/"

# %%
syn = pd.read_json(DATA_PATH + "claims_syn_all_dedup.jsonl", lines=True)

# %%
syn
# Out:
#                                                    claim cited_doc_ids
# 0      Did the preterm group at term have higher or l...        [4983]
# 1      What was the mean apparent diffusion coefficie...        [4983]
# 2      What was the mean apparent diffusion coefficie...        [4983]
# 3      What was the mean apparent diffusion coefficie...        [4983]
# 4      What was the difference in mean apparent diffu...        [4983]
# ...                                                  ...           ...
# 99221  Is the social adaptation hypothesis that peopl...   [154243324]
# 99222  How does the paper's finding relate to the soc...   [154243324]
# 99223  What is the main criticism of early interventi...   [154243324]
# 99224  What percentage of the sample were young adult...   [154243324]
# 99225  What does the paper conclude about the social ...   [154243324]
#
# [99226 rows x 2 columns]

# %%
train = pd.read_json(DATA_PATH + "claims_train.jsonl", lines=True)

# %%
syn
# Out:
#                                                    claim cited_doc_ids
# 0      Did the preterm group at term have higher or l...        [4983]
# 1      What was the mean apparent diffusion coefficie...        [4983]
# 2      What was the mean apparent diffusion coefficie...        [4983]
# 3      What was the mean apparent diffusion coefficie...        [4983]
# 4      What was the difference in mean apparent diffu...        [4983]
# ...                                                  ...           ...
# 99221  Is the social adaptation hypothesis that peopl...   [154243324]
# 99222  How does the paper's finding relate to the soc...   [154243324]
# 99223  What is the main criticism of early interventi...   [154243324]
# 99224  What percentage of the sample were young adult...   [154243324]
# 99225  What does the paper conclude about the social ...   [154243324]
#
# [99226 rows x 2 columns]

# %%
train
# Out:
#        id                                              claim  \
# 0       0  0-dimensional biomaterials lack inductive prop...
# 1       2  1 in 5 million in UK have abnormal PrP positiv...
# 2       4  1-1% of colorectal cancer patients are diagnos...
# 3       6  10% of sudden infant death syndrome (SIDS) dea...
# 4       9  32% of liver transplantation programs required...
# ..    ...                                                ...
# 804  1403  siRNA knockdown of A20 accelerates tumor progr...
# 805  1404  siRNA knockdown of A20 slows tumor progression...
# 806  1405  taa1 tar1 tar2 triple mutants in Arabidopsis d...
# 807  1406  β-sheet opening occurs during pleurotolysin po...
# 808  1407             β1/Ketel is able to bind microtubules.
#
#                                               evidence        cited_doc_ids
# 0                                                   {}           [31715818]
# 1    {'13734012': [{'sentences': [4], 'label': 'CON...           [13734012]
# ...

# %%
combined_df = pd.concat([syn, train], ignore_index=True)

# %%
combined_df
# Out:
#                                                     claim  \
# 0       Did the preterm group at term have higher or l...
# 1       What was the mean apparent diffusion coefficie...
# 2       What was the mean apparent diffusion coefficie...
# 3       What was the mean apparent diffusion coefficie...
# 4       What was the difference in mean apparent diffu...
# ...                                                   ...
# 100030  siRNA knockdown of A20 accelerates tumor progr...
# 100031  siRNA knockdown of A20 slows tumor progression...
# 100032  taa1 tar1 tar2 triple mutants in Arabidopsis d...
# 100033  β-sheet opening occurs during pleurotolysin po...
# 100034             β1/Ketel is able to bind microtubules.
#
#               cited_doc_ids      id  \
# 0                    [4983]     NaN
# 1                    [4983]     NaN
# 2                    [4983]     NaN
# 3                    [4983]     NaN
# 4                    [4983]     NaN
# ...                     ...     ...
# ...

# %%
100035 / 800
# Out:
# 125.04375
